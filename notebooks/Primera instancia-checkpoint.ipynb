# %%
# Librerias

# %%
# !pip install numpy pandas
# Out:
# ...
#      ---------------------------------------- 0.0/60.9 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.9 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/60.9 kB 131.3 kB/s eta 0:00:01
#      ------------------- ------------------ 30.7/60.9 kB 163.8 kB/s eta 0:00:01
#      ------------------------- ------------ 41.0/60.9 kB 196.9 kB/s eta 0:00:01
#      -------------------------------------- 60.9/60.9 kB 231.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/16.2 MB ? eta -:--:--
#    ---------------------------------------- 0.1/16.2 MB 2.4 MB/s eta 0:00:07
#    - -------------------------------------- 0.6/16.2 MB 6.1 MB/s eta 0:00:03
#    -- ------------------------------------- 0.9/16.2 MB 6.8 MB/s eta 0:00:03
#    --- ------------------------------------ 1.4/16.2 MB 8.9 MB/s eta 0:00:02
#    ---- ----------------------------------- 1.9/16.2 MB 8.1 MB/s eta 0:00:02
# ...

# %%
import numpy as np
import pandas as pd

# %%
# Primer dataset

df_card = pd.read_csv(r'C:\\Users\\Dario\\Desktop\\Proyecto No contry\\Datasets\\Dataset1.csv')
df_card.head(10)
# Out:
#         ID  Gender  Own_car  Own_property  Work_phone  Phone  Email  \
# 0  5008804       1        1             1           1      0      0
# 1  5008806       1        1             1           0      0      0
# 2  5008808       0        0             1           0      1      1
# 3  5008812       0        0             1           0      0      0
# 4  5008815       1        1             1           1      1      1
# 5  5008819       1        1             1           0      0      0
# 6  5008825       0        1             0           0      0      0
# 7  5008830       0        0             1           0      1      0
# 8  5008834       0        0             1           0      0      0
# 9  5008836       1        1             1           0      0      0
#
#    Unemployed  Num_children  Num_family  Account_length  Total_income  \
# 0           0             0           2              15      427500.0
# 1           0             0           2              29      112500.0
# ...

# %%
# Segundo dataset

df_house = pd.read_csv(r'C:\\Users\\Dario\\Desktop\\Proyecto No contry\\Datasets\\Dataset2.csv')
df_house.head(10)
# Out:
#    CLIENTNUM     Attrition_Flag  Customer_Age Gender  Dependent_count  \
# 0  768805383  Existing Customer            45      M                3
# 1  818770008  Existing Customer            49      F                5
# 2  713982108  Existing Customer            51      M                3
# 3  769911858  Existing Customer            40      F                4
# 4  709106358  Existing Customer            40      M                3
# 5  713061558  Existing Customer            44      M                2
# 6  810347208  Existing Customer            51      M                4
# 7  818906208  Existing Customer            32      M                0
# 8  710930508  Existing Customer            37      M                3
# 9  719661558  Existing Customer            48      M                2
#
#   Education_Level Marital_Status Income_Category Card_Category  \
# 0     High School        Married     $60K - $80K          Blue
# 1        Graduate         Single  Less than $40K          Blue
# ...

# %% [markdown]
# #### Voy a unir a los dos datasets mediante una clave común. Para crear esta clave común voy a unir 'Gender','Age'y Marital_Status en df_house(el segundo dataset) y sus equivalentes en df_card (primer dataset).

# %%
# Normalizamos las columnas Gender
df_card['Gender'] = df_card['Gender'].replace({1: 'M', 0: 'F'}) #Transfomramos en 0 y 1

# Normalizamos las columnas de edad (convertir las edades en enteros)
df_card['Age'] = df_card['Age'].astype(int)
df_house['Customer_Age'] = df_house['Customer_Age'].astype(int)

# Unimos los datasets basados en columnas comunes que mencione antes (Gender, Age, Marital Status)
#'Family_status' en df_card y 'Marital_Status' en df_house se consideran equivalentes

# Combinamos los datasets con las columnas normalizadas
df = pd.merge(df_card, df_house, left_on=['Gender', 'Age', 'Family_status'], right_on=['Gender', 'Customer_Age', 'Marital_Status'], how='inner')

# Primeras filas del dataframe nuevo
df.head()
# Out:
#         ID Gender  Own_car  Own_property  Work_phone  Phone  Email  \
# 0  5008806      M        1             1           0      0      0
# 1  5008806      M        1             1           0      0      0
# 2  5008806      M        1             1           0      0      0
# 3  5008806      M        1             1           0      0      0
# 4  5008806      M        1             1           0      0      0
#
#    Unemployed  Num_children  Num_family  ...  Credit_Limit  \
# 0           0             0           2  ...       12555.0
# 1           0             0           2  ...       24407.0
# 2           0             0           2  ...        1438.3
# 3           0             0           2  ...       10021.0
# 4           0             0           2  ...       12010.0
#
#    Total_Revolving_Bal  Avg_Open_To_Buy  Total_Amt_Chng_Q4_Q1 Total_Trans_Amt  \
# 0                 1696          10859.0                 0.519            1291
# ...

# %% [markdown]
# ### Pude crear el dataset, lo que no realicé fue el analisis exploratorio ni examine el dataset, a partir de mañana sacamos concluciones y vemos que podemos hacer! :)
